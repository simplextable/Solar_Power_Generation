# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv("Plant_1_Generation_Data.csv")
df1_weather = pd.read_csv("Plant_1_Weather_Sensor_Data.csv")
df2 = pd.read_csv("Plant_2_Generation_Data.csv")
df2_weather = pd.read_csv("Plant_2_Weather_Sensor_Data.csv")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
pd.set_option("display.max_rows",500)
pd.set_option("display.max_columns",50)

# %%
df1_weather
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0     2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1     2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2     2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3     2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4     2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
# ...                   ...       ...              ...                  ...
# 3177  2020-06-17 22:45:00   4135001  HmiyD2TTLFNqkNe            22.150570
# 3178  2020-06-17 23:00:00   4135001  HmiyD2TTLFNqkNe            22.129816
# 3179  2020-06-17 23:15:00   4135001  HmiyD2TTLFNqkNe            22.008275
# 3180  2020-06-17 23:30:00   4135001  HmiyD2TTLFNqkNe            21.969495
# 3181  2020-06-17 23:45:00   4135001  HmiyD2TTLFNqkNe            21.909288
#
#       MODULE_TEMPERATURE  IRRADIATION
# 0              22.857507          0.0
# ...

# %%
df2_weather
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0     2020-05-15 00:00:00   4136001  iq8k7ZNt4Mwm3w0            27.004764
# 1     2020-05-15 00:15:00   4136001  iq8k7ZNt4Mwm3w0            26.880811
# 2     2020-05-15 00:30:00   4136001  iq8k7ZNt4Mwm3w0            26.682055
# 3     2020-05-15 00:45:00   4136001  iq8k7ZNt4Mwm3w0            26.500589
# 4     2020-05-15 01:00:00   4136001  iq8k7ZNt4Mwm3w0            26.596148
# ...                   ...       ...              ...                  ...
# 3254  2020-06-17 22:45:00   4136001  iq8k7ZNt4Mwm3w0            23.511703
# 3255  2020-06-17 23:00:00   4136001  iq8k7ZNt4Mwm3w0            23.482282
# 3256  2020-06-17 23:15:00   4136001  iq8k7ZNt4Mwm3w0            23.354743
# 3257  2020-06-17 23:30:00   4136001  iq8k7ZNt4Mwm3w0            23.291048
# 3258  2020-06-17 23:45:00   4136001  iq8k7ZNt4Mwm3w0            23.202871
#
#       MODULE_TEMPERATURE  IRRADIATION
# 0              25.060789          0.0
# ...

# %%
# pd.set_option("display.max_rows",70000000)  # KISALTMA ENGELLEME
# pd.set_option("display.max_columns",2200)  # KISALTMA ENGELLEME

# %%
df1.drop(columns=["PLANT_ID"], inplace=True)
df2.drop(columns=["PLANT_ID"], inplace=True)

# %%
df1["SOURCE_KEY"].unique()
# Out:
# array(['1BY6WEcLGh8j5v7', '1IF53ai7Xc0U56Y', '3PZuoBAID5Wc2HD',
#        '7JYdWkrLSPkdwr4', 'McdE0feGgRqW7Ca', 'VHMLBKoKgIrUVDU',
#        'WRmjgnKYAwPKWDb', 'ZnxXDlPa8U1GXgE', 'ZoEaEvLYb1n2sOq',
#        'adLQvlD726eNBSB', 'bvBOhCH3iADSZry', 'iCRJl6heRkivqQ3',
#        'ih0vzX44oOqAx2f', 'pkci93gMrogZuBj', 'rGa61gmuvPhdLxV',
#        'sjndEbLyjtCKgGv', 'uHbuxQJl8lW7ozc', 'wCURE6d3bPkepu2',
#        'z9Y9gH1T5YWrNuG', 'zBIq5rxdHJRwDNY', 'zVJPv84UY57bAof',
#        'YxYtjZvoooNbGkE'], dtype=object)

# %%
df2["SOURCE_KEY"].unique()
# Out:
# array(['4UPUqMRk7TRMgml', '81aHJ1q11NBPMrL', '9kRcWv60rDACzjR',
#        'Et9kgGMDl729KT4', 'IQ2d7wF4YD8zU1Q', 'LYwnQax7tkwH5Cb',
#        'LlT2YUhhzqhg5Sw', 'Mx2yZCDsyf6DPfv', 'NgDl19wMapZy17u',
#        'PeE6FRyGXUgsRhN', 'Qf4GUc1pJu5T6c6', 'Quc1TzYxW2pYoWX',
#        'V94E5Ben1TlhnDV', 'WcxssY2VbP4hApt', 'mqwcsP2rE7J0TFp',
#        'oZ35aAeoifZaQzV', 'oZZkBaNadn6DNKz', 'q49J1IKaHRwDQnt',
#        'rrq4fwE8jgrTyWY', 'vOuJvMaM2sgwLmb', 'xMbIugepa2P7lBB',
#        'xoJJ8DcxJEcupym'], dtype=object)

# %%
df1[df1["SOURCE_KEY"].isin(df2["SOURCE_KEY"])]
# Out:
# Empty DataFrame
# Columns: [DATE_TIME, SOURCE_KEY, DC_POWER, AC_POWER, DAILY_YIELD, TOTAL_YIELD]
# Index: []

# %%
df1
# Out:
#               DATE_TIME       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 0      15-05-2020 00:00  1BY6WEcLGh8j5v7       0.0       0.0        0.000
# 1      15-05-2020 00:00  1IF53ai7Xc0U56Y       0.0       0.0        0.000
# 2      15-05-2020 00:00  3PZuoBAID5Wc2HD       0.0       0.0        0.000
# 3      15-05-2020 00:00  7JYdWkrLSPkdwr4       0.0       0.0        0.000
# 4      15-05-2020 00:00  McdE0feGgRqW7Ca       0.0       0.0        0.000
# ...                 ...              ...       ...       ...          ...
# 68773  17-06-2020 23:45  uHbuxQJl8lW7ozc       0.0       0.0     5967.000
# 68774  17-06-2020 23:45  wCURE6d3bPkepu2       0.0       0.0     5147.625
# 68775  17-06-2020 23:45  z9Y9gH1T5YWrNuG       0.0       0.0     5819.000
# 68776  17-06-2020 23:45  zBIq5rxdHJRwDNY       0.0       0.0     5817.000
# 68777  17-06-2020 23:45  zVJPv84UY57bAof       0.0       0.0     5910.000
#
#        TOTAL_YIELD
# 0        6259559.0
# 1        6183645.0
# ...

# %%
df1
# Out:
#               DATE_TIME       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 0      15-05-2020 00:00  1BY6WEcLGh8j5v7       0.0       0.0        0.000
# 1      15-05-2020 00:00  1IF53ai7Xc0U56Y       0.0       0.0        0.000
# 2      15-05-2020 00:00  3PZuoBAID5Wc2HD       0.0       0.0        0.000
# 3      15-05-2020 00:00  7JYdWkrLSPkdwr4       0.0       0.0        0.000
# 4      15-05-2020 00:00  McdE0feGgRqW7Ca       0.0       0.0        0.000
# ...                 ...              ...       ...       ...          ...
# 68773  17-06-2020 23:45  uHbuxQJl8lW7ozc       0.0       0.0     5967.000
# 68774  17-06-2020 23:45  wCURE6d3bPkepu2       0.0       0.0     5147.625
# 68775  17-06-2020 23:45  z9Y9gH1T5YWrNuG       0.0       0.0     5819.000
# 68776  17-06-2020 23:45  zBIq5rxdHJRwDNY       0.0       0.0     5817.000
# 68777  17-06-2020 23:45  zVJPv84UY57bAof       0.0       0.0     5910.000
#
#        TOTAL_YIELD            datetime
# 0        6259559.0 2020-05-15 00:00:00
# ...

# %%
df2
# Out:
#                  DATE_TIME       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 0      2020-05-15 00:00:00  4UPUqMRk7TRMgml       0.0       0.0  9425.000000
# 1      2020-05-15 00:00:00  81aHJ1q11NBPMrL       0.0       0.0     0.000000
# 2      2020-05-15 00:00:00  9kRcWv60rDACzjR       0.0       0.0  3075.333333
# 3      2020-05-15 00:00:00  Et9kgGMDl729KT4       0.0       0.0   269.933333
# 4      2020-05-15 00:00:00  IQ2d7wF4YD8zU1Q       0.0       0.0  3177.000000
# ...                    ...              ...       ...       ...          ...
# 67693  2020-06-17 23:45:00  q49J1IKaHRwDQnt       0.0       0.0  4157.000000
# 67694  2020-06-17 23:45:00  rrq4fwE8jgrTyWY       0.0       0.0  3931.000000
# 67695  2020-06-17 23:45:00  vOuJvMaM2sgwLmb       0.0       0.0  4322.000000
# 67696  2020-06-17 23:45:00  xMbIugepa2P7lBB       0.0       0.0  4218.000000
# 67697  2020-06-17 23:45:00  xoJJ8DcxJEcupym       0.0       0.0  4316.000000
#
#         TOTAL_YIELD
# 0      2.429011e+06
# ...

# %%
from datetime import datetime
df2["datetime"] = pd.to_datetime(pd.Series(df2["DATE_TIME"]), format='%Y-%m-%d %H:%M:%S')
df1["datetime"] = pd.to_datetime(pd.Series(df1["DATE_TIME"]), format='%d-%m-%Y %H:%M')

# %%
df1["datetime"] = pd.to_datetime(pd.Series(df1["DATE_TIME"]), format='%d-%m-%Y %H:%M')
# Out:
#               DATE_TIME       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 0   2020-05-15 00:00:00  4UPUqMRk7TRMgml       0.0       0.0  9425.000000
# 1   2020-05-15 00:00:00  81aHJ1q11NBPMrL       0.0       0.0     0.000000
# 2   2020-05-15 00:00:00  9kRcWv60rDACzjR       0.0       0.0  3075.333333
# 3   2020-05-15 00:00:00  Et9kgGMDl729KT4       0.0       0.0   269.933333
# 4   2020-05-15 00:00:00  IQ2d7wF4YD8zU1Q       0.0       0.0  3177.000000
# 5   2020-05-15 00:00:00  LYwnQax7tkwH5Cb       0.0       0.0  1872.500000
# 6   2020-05-15 00:00:00  LlT2YUhhzqhg5Sw       0.0       0.0  1094.357143
# 7   2020-05-15 00:00:00  Mx2yZCDsyf6DPfv       0.0       0.0  5692.200000
# 8   2020-05-15 00:00:00  NgDl19wMapZy17u       0.0       0.0  1866.200000
# 9   2020-05-15 00:00:00  PeE6FRyGXUgsRhN       0.0       0.0   651.200000
# 10  2020-05-15 00:00:00  Qf4GUc1pJu5T6c6       0.0       0.0     0.000000
# 11  2020-05-15 00:00:00  Quc1TzYxW2pYoWX       0.0       0.0  5495.000000
# ...

# %%
df1["datetime"].unique()
# Out:
# array(['2020-05-15T00:00:00.000000000', '2020-05-15T00:15:00.000000000',
#        '2020-05-15T00:30:00.000000000', ...,
#        '2020-06-17T23:15:00.000000000', '2020-06-17T23:30:00.000000000',
#        '2020-06-17T23:45:00.000000000'], dtype='datetime64[ns]')

# %%
df2["datetime"].unique()
# Out:
# array(['2020-05-15T00:00:00.000000000', '2020-05-15T00:15:00.000000000',
#        '2020-05-15T00:30:00.000000000', ...,
#        '2020-06-17T23:15:00.000000000', '2020-06-17T23:30:00.000000000',
#        '2020-06-17T23:45:00.000000000'], dtype='datetime64[ns]')

# %%
df1[~df1["datetime"].isin(df2["datetime"].unique())]["datetime"].unique()
# Out:
# array(['2020-05-19T16:00:00.000000000', '2020-05-29T16:00:00.000000000',
#        '2020-06-01T17:45:00.000000000', '2020-06-03T14:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
df2[~df2["datetime"].isin(df1["datetime"].unique())]["datetime"].unique()
# Out:
# array(['2020-05-15T23:30:00.000000000', '2020-05-15T23:45:00.000000000',
#        '2020-05-16T00:00:00.000000000', '2020-05-16T00:15:00.000000000',
#        '2020-05-16T00:30:00.000000000', '2020-05-16T00:45:00.000000000',
#        '2020-05-16T01:00:00.000000000', '2020-05-16T01:15:00.000000000',
#        '2020-05-16T01:30:00.000000000', '2020-05-16T01:45:00.000000000',
#        '2020-05-19T11:45:00.000000000', '2020-05-19T12:00:00.000000000',
#        '2020-05-19T12:15:00.000000000', '2020-05-20T13:30:00.000000000',
#        '2020-05-20T13:45:00.000000000', '2020-05-20T14:00:00.000000000',
#        '2020-05-20T14:15:00.000000000', '2020-05-20T14:30:00.000000000',
#        '2020-05-20T14:45:00.000000000', '2020-05-20T15:00:00.000000000',
#        '2020-05-20T15:15:00.000000000', '2020-05-20T15:30:00.000000000',
#        '2020-05-20T15:45:00.000000000', '2020-05-20T16:00:00.000000000',
#        '2020-05-20T16:15:00.000000000', '2020-05-20T16:30:00.000000000',
# ...

# %%
df1[df1["SOURCE_KEY"] == "1BY6WEcLGh8j5v7"].loc[1500:2000]
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY     DC_POWER    AC_POWER  \
# 1520  15-05-2020 17:30   4135001  1BY6WEcLGh8j5v7  1091.000000  106.066667
# 1542  15-05-2020 17:45   4135001  1BY6WEcLGh8j5v7   485.875000   47.012500
# 1564  15-05-2020 18:00   4135001  1BY6WEcLGh8j5v7   264.000000   25.485714
# 1586  15-05-2020 18:15   4135001  1BY6WEcLGh8j5v7    78.285714    7.542857
# 1608  15-05-2020 18:30   4135001  1BY6WEcLGh8j5v7     0.000000    0.000000
# 1630  15-05-2020 18:45   4135001  1BY6WEcLGh8j5v7     0.000000    0.000000
# 1652  15-05-2020 19:00   4135001  1BY6WEcLGh8j5v7     0.000000    0.000000
# 1666  15-05-2020 19:15   4135001  1BY6WEcLGh8j5v7     0.000000    0.000000
# 1680  15-05-2020 19:30   4135001  1BY6WEcLGh8j5v7     0.000000    0.000000
# 1694  15-05-2020 19:45   4135001  1BY6WEcLGh8j5v7     0.000000    0.000000
# 1708  15-05-2020 20:00   4135001  1BY6WEcLGh8j5v7     0.000000    0.000000
# ...

# %%
df1.head()
# Out:
#           DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD  unit_time_yield
# 0          0.0    6259559.0                0
# 1          0.0    6183645.0                0
# 2          0.0    6987759.0                0
# 3          0.0    7602960.0                0
# 4          0.0    7158964.0                0

# %%
roll_diff = pd.Series(df1.DAILY_YIELD).diff(periods=1)

# %%
roll_diff
# Out:
# 0            NaN
# 1          0.000
# 2          0.000
# 3          0.000
# 4          0.000
#           ...
# 68773     80.000
# 68774   -819.375
# 68775    671.375
# 68776     -2.000
# 68777     93.000
# Name: DAILY_YIELD, Length: 68778, dtype: float64

# %%
df1['diffs'] = df1.groupby('SOURCE_KEY')['DAILY_YIELD'].diff()

# %%
df1
# Out:
#               DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0      15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1      15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2      15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3      15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4      15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
# ...                 ...       ...              ...       ...       ...
# 68773  17-06-2020 23:45   4135001  uHbuxQJl8lW7ozc       0.0       0.0
# 68774  17-06-2020 23:45   4135001  wCURE6d3bPkepu2       0.0       0.0
# 68775  17-06-2020 23:45   4135001  z9Y9gH1T5YWrNuG       0.0       0.0
# 68776  17-06-2020 23:45   4135001  zBIq5rxdHJRwDNY       0.0       0.0
# 68777  17-06-2020 23:45   4135001  zVJPv84UY57bAof       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD  unit_time_yield    diffs
# ...

# %%
df1.loc[0:450]
# Out:
#             DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0    15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1    15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2    15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3    15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4    15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
# 5    15-05-2020 00:00   4135001  VHMLBKoKgIrUVDU       0.0       0.0
# 6    15-05-2020 00:00   4135001  WRmjgnKYAwPKWDb       0.0       0.0
# 7    15-05-2020 00:00   4135001  ZnxXDlPa8U1GXgE       0.0       0.0
# 8    15-05-2020 00:00   4135001  ZoEaEvLYb1n2sOq       0.0       0.0
# 9    15-05-2020 00:00   4135001  adLQvlD726eNBSB       0.0       0.0
# 10   15-05-2020 00:00   4135001  bvBOhCH3iADSZry       0.0       0.0
# 11   15-05-2020 00:00   4135001  iCRJl6heRkivqQ3       0.0       0.0
# 12   15-05-2020 00:00   4135001  ih0vzX44oOqAx2f       0.0       0.0
# ...

# %%
df1_1 = df1[df1.SOURCE_KEY == "1BY6WEcLGh8j5v7"]

# %%
df1_1
# Out:
#               DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0      15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 21     15-05-2020 00:15   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 42     15-05-2020 00:30   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 63     15-05-2020 00:45   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 84     15-05-2020 01:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# ...                 ...       ...              ...       ...       ...
# 68668  17-06-2020 22:45   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 68690  17-06-2020 23:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 68712  17-06-2020 23:15   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 68734  17-06-2020 23:30   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 68756  17-06-2020 23:45   4135001  1BY6WEcLGh8j5v7       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD  unit_time_yield  diffs            datetime
# ...

# %%
df1_2 = df1_1[["datetime", "DAILY_YIELD"]]

# %%
df1_2
# Out:
#                  datetime  DAILY_YIELD
# 0     2020-05-15 00:00:00          0.0
# 21    2020-05-15 00:15:00          0.0
# 42    2020-05-15 00:30:00          0.0
# 63    2020-05-15 00:45:00          0.0
# 84    2020-05-15 01:00:00          0.0
# ...                   ...          ...
# 68668 2020-06-17 22:45:00       5521.0
# 68690 2020-06-17 23:00:00       5521.0
# 68712 2020-06-17 23:15:00       5521.0
# 68734 2020-06-17 23:30:00       5521.0
# 68756 2020-06-17 23:45:00       5521.0
#
# [3154 rows x 2 columns]

# %%
df1_3 = df1_2.resample('D', on='datetime').max()

# %%
df1_3
# Out:
#                       datetime  DAILY_YIELD
# datetime
# 2020-05-15 2020-05-15 23:00:00  5754.000000
# 2020-05-16 2020-05-16 23:45:00  6292.000000
# 2020-05-17 2020-05-17 23:45:00  7045.000000
# 2020-05-18 2020-05-18 23:45:00  4998.000000
# 2020-05-19 2020-05-19 23:45:00  6449.000000
# 2020-05-20 2020-05-20 22:45:00  8249.000000
# 2020-05-21 2020-05-21 23:45:00  7243.000000
# 2020-05-22 2020-05-22 23:45:00  6848.000000
# 2020-05-23 2020-05-23 23:45:00  7966.000000
# 2020-05-24 2020-05-24 23:45:00  7537.000000
# 2020-05-25 2020-05-25 23:45:00  8268.000000
# 2020-05-26 2020-05-26 23:45:00  7456.428571
# 2020-05-27 2020-05-27 23:45:00  6164.000000
# 2020-05-28 2020-05-28 22:15:00  7977.000000
# 2020-05-29 2020-05-29 23:45:00  7564.000000
# 2020-05-30 2020-05-30 23:45:00  6754.000000
# 2020-05-31 2020-05-31 23:45:00  5803.000000
# 2020-06-01 2020-06-01 23:45:00  5508.000000
# 2020-06-02 2020-06-02 23:45:00  7029.000000
# 2020-06-03 2020-06-03 23:45:00  7341.000000
# ...

# %%
df1_weather["datetime"] = pd.to_datetime(pd.Series(df1_weather["DATE_TIME"]), format='%Y-%m-%d %H:%M:%S')

# %%
del df1_weather["DATE_TIME"]

# %%
df1_weather.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1  2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2  2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3  2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4  2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION            datetime
# 0           22.857507          0.0 2020-05-15 00:00:00
# 1           22.761668          0.0 2020-05-15 00:15:00
# 2           22.592306          0.0 2020-05-15 00:30:00
# 3           22.360852          0.0 2020-05-15 00:45:00
# 4           22.165423          0.0 2020-05-15 01:00:00

# %%
df1_weather_1 = df1_weather[["datetime", "AMBIENT_TEMPERATURE", "MODULE_TEMPERATURE", "IRRADIATION"]]

# %%
df1_weather_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   datetime             3182 non-null   datetime64[ns]
#  1   AMBIENT_TEMPERATURE  3182 non-null   float64
#  2   MODULE_TEMPERATURE   3182 non-null   float64
#  3   IRRADIATION          3182 non-null   float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 99.6 KB

# %%
df1_weather_2 = df1_weather_1.resample('D', on='datetime').mean()

# %%
df1_weather_2.head()
# Out:
#             AMBIENT_TEMPERATURE  MODULE_TEMPERATURE
# datetime
# 2020-05-15            27.430823           32.582964
# 2020-05-16            26.780538           31.858851
# 2020-05-17            26.686727           32.740435
# 2020-05-18            23.850938           27.814344
# 2020-05-19            25.338021           29.725163

# %%
del df1_weather_2["IRRADIATION"]

# %%
df1_weather_2["Irradiation_Sum"] = df1_weather_1.resample('D', on='datetime').sum()["IRRADIATION"]

# %%
df1_weather_2
# Out:
#             AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  Irradiation_Sum
# datetime
# 2020-05-15            27.430823           32.582964        19.037010
# 2020-05-16            26.780538           31.858851        18.651690
# 2020-05-17            26.686727           32.740435        22.931378
# 2020-05-18            23.850938           27.814344        15.266485
# 2020-05-19            25.338021           29.725163        18.044861
# 2020-05-20            25.076782           29.332088        18.245542
# 2020-05-21            27.737575           37.186870        23.556170
# 2020-05-22            26.526703           32.478885        22.119123
# 2020-05-23            26.839617           34.801843        26.106652
# 2020-05-24            27.625116           33.978544        24.937180
# 2020-05-25            27.210157           34.533963        27.233366
# 2020-05-26            26.904455           33.473154        24.250589
# ...

# %%
df1_weather_2["daily_yield"] = df1_3["DAILY_YIELD"]

# %%
df1_4.head()
# Out:
#             DAILY_YIELD
# datetime
# 2020-05-15       5754.0
# 2020-05-16       6292.0
# 2020-05-17       7045.0
# 2020-05-18       4998.0
# 2020-05-19       6449.0

# %%
df1_4 = df1_3[["DAILY_YIELD"]]

# %%
df1_weather_2.head()
# Out:
#             AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  Irradiation_Sum
# datetime
# 2020-05-15            27.430823           32.582964        19.037010
# 2020-05-16            26.780538           31.858851        18.651690
# 2020-05-17            26.686727           32.740435        22.931378
# 2020-05-18            23.850938           27.814344        15.266485
# 2020-05-19            25.338021           29.725163        18.044861

# %%
df_merge = df1_4.merge(df1_weather_2, left_on='datetime', right_on='datetime')

# %%
# Out:
#             DAILY_YIELD  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# datetime
# 2020-05-15       5754.0            27.430823           32.582964
# 2020-05-16       6292.0            26.780538           31.858851
# 2020-05-17       7045.0            26.686727           32.740435
# 2020-05-18       4998.0            23.850938           27.814344
# 2020-05-19       6449.0            25.338021           29.725163
#
#             Irradiation_Sum
# datetime
# 2020-05-15        19.037010
# 2020-05-16        18.651690
# 2020-05-17        22.931378
# 2020-05-18        15.266485
# 2020-05-19        18.044861

# %%
df1_weather_2 = df1_weather_1.resample('D', on='datetime').mean()

# %%
df1_weather_1.head()
# Out:
#              DATE_TIME  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# 0  2020-05-15 00:00:00            25.184316           22.857507
# 1  2020-05-15 00:15:00            25.084589           22.761668
# 2  2020-05-15 00:30:00            24.935753           22.592306
# 3  2020-05-15 00:45:00            24.846130           22.360852
# 4  2020-05-15 01:00:00            24.621525           22.165423
#
#              datetime
# 0 2020-05-15 00:00:00
# 1 2020-05-15 00:15:00
# 2 2020-05-15 00:30:00
# 3 2020-05-15 00:45:00
# 4 2020-05-15 01:00:00

# %%
df1_weather_3 = df1_weather_1.resample('D', on='datetime').mean()

# %%
df1_weather_2.head()
# Out:
#             AMBIENT_TEMPERATURE  MODULE_TEMPERATURE
# datetime
# 2020-05-15            27.430823           32.582964
# 2020-05-16            26.780538           31.858851
# 2020-05-17            26.686727           32.740435
# 2020-05-18            23.850938           27.814344
# 2020-05-19            25.338021           29.725163

# %%
df1_3.head()
# Out:
#                       datetime  DAILY_YIELD
# datetime
# 2020-05-15 2020-05-15 23:00:00       5754.0
# 2020-05-16 2020-05-16 23:45:00       6292.0
# 2020-05-17 2020-05-17 23:45:00       7045.0
# 2020-05-18 2020-05-18 23:45:00       4998.0
# 2020-05-19 2020-05-19 23:45:00       6449.0

# %%
df1_weather_1.head(50)
# Out:
#               DATE_TIME  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# 0   2020-05-15 00:00:00            25.184316           22.857507
# 1   2020-05-15 00:15:00            25.084589           22.761668
# 2   2020-05-15 00:30:00            24.935753           22.592306
# 3   2020-05-15 00:45:00            24.846130           22.360852
# 4   2020-05-15 01:00:00            24.621525           22.165423
# 5   2020-05-15 01:15:00            24.536092           21.968571
# 6   2020-05-15 01:30:00            24.638674           22.352926
# 7   2020-05-15 01:45:00            24.873022           23.160919
# 8   2020-05-15 02:00:00            24.936930           23.026113
# 9   2020-05-15 02:15:00            25.012248           23.343229
# 10  2020-05-15 02:30:00            25.005149           23.639459
# 11  2020-05-15 02:45:00            24.993020           24.039486
# 12  2020-05-15 03:00:00            25.016309           24.384136
# ...

# %%
 df1_2.resample('D', on='datetime').max()

# %%
#Gelecek 15 Günün Tahmini
#Arıza ile ilgili Tahmin, anomali detection

# %%
df1_weather.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1  2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2  2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3  2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4  2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION
# 0           22.857507          0.0
# 1           22.761668          0.0
# 2           22.592306          0.0
# 3           22.360852          0.0
# 4           22.165423          0.0

# %%
df_merge.head()
# Out:
#             DAILY_YIELD  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# datetime
# 2020-05-15       5754.0            27.430823           32.582964
# 2020-05-16       6292.0            26.780538           31.858851
# 2020-05-17       7045.0            26.686727           32.740435
# 2020-05-18       4998.0            23.850938           27.814344
# 2020-05-19       6449.0            25.338021           29.725163
#
#             Irradiation_Sum
# datetime
# 2020-05-15        19.037010
# 2020-05-16        18.651690
# 2020-05-17        22.931378
# 2020-05-18        15.266485
# 2020-05-19        18.044861

# %%
from matplotlib import pyplot
# Out:
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# ...

# %%
pyplot.plot(df_merge[["DAILY_YIELD"]])
pyplot.show()
